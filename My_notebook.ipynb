# %%
from utils import *

set_dirname('data/Nouzilly_subs')

compare('2refs_sc0', '3refs_sc0')
compare('2refs_sc0', '3refs_sc10')
plot_fit('3refs_sc0')

print_available()
# Out:
# Available data:
# Zn_Nouzilly_subs_LCF_2refs_sc0.lcf
# Zn_Nouzilly_subs_LCF_3refs_sc0.lcf
# Zn_Nouzilly_subs_LCF_3refs_sc10.lcf
# Zn_Nouzilly_subs_LCF_3refs_sc3.lcf
# Zn_Nouzilly_subs_LCF_3refs_sc5.lcf
# Zn_Nouzilly_subs_LCF_3refs_sc7.lcf
# Zn_Nouzilly_subs_LCF_4refsnp51ald_sc0.lcf
