# %%
from utils import *
# Out:
# <script>
#         var code_show=false; //true -> show code at first
#
#         function code_toggle() {
#             $('div.prompt').hide(); // always hide prompt
#
#             if (code_show){
#                 $('div.input').hide();
#             } else {
#                 $('div.input').show();
#             }
#             code_show = !code_show
#         }
#         $( document ).ready(code_toggle);
#     </script><a href="javascript:code_toggle()">[Toggle Code]</a>
# Available globals: `HTML`,`Latex`,`compare`,`plt`,`add_hide`,`show_available`,`g1`,`display`,`osp`,`plot_fit`,`Markdown`,`set_dirname`,`ipython`,`parse_lcf`,`os`,`get_file`,`pl`

# %%
set_dirname('data/Nouzilly_subs')
show_available()
# Out:
# Available data:
#
# * `Zn_Nouzilly_subs_LCF_2refs_sc0.lcf`
# * `Zn_Nouzilly_subs_LCF_3refs_sc0.lcf`
# * `Zn_Nouzilly_subs_LCF_3refs_sc10.lcf`
# * `Zn_Nouzilly_subs_LCF_3refs_sc3.lcf`
# * `Zn_Nouzilly_subs_LCF_3refs_sc5.lcf`
# * `Zn_Nouzilly_subs_LCF_3refs_sc7.lcf`
# * `Zn_Nouzilly_subs_LCF_4refsnp51ald_sc0.lcf`

# %%
compare('2refs_sc0', '3refs_sc0')
compare('2refs_sc0', '3refs_sc10')
plot_fit('3refs_sc0')
